# %%
import pandas as pd
df=pd.read_excel("02_Microsoft.xlsx")
df
# Out:
#           Date  Close/Last    Volume     Open    High       Low
# 0   2018-01-02       85.95  22122680   86.125   86.31   85.5000
# 1   2018-01-03       86.35  25979960   86.055   86.51   85.9700
# 2   2018-01-04       87.11  21904860   86.590   87.66   86.5700
# 3   2018-01-05       88.19  23400070   87.660   88.41   87.4300
# 4   2018-01-08       88.28  22110230   88.200   88.58   87.6046
# ..         ...         ...       ...      ...     ...       ...
# 246 2018-12-24       94.13  43935190   97.680   97.97   93.9800
# 247 2018-12-26      100.56  51330280   95.140  100.69   93.9600
# 248 2018-12-27      101.18  49162950   99.300  101.19   96.4000
# 249 2018-12-28      100.39  38160810  102.090  102.41   99.5200
# 250 2018-12-31      101.57  33161320  101.290  102.40  100.4400
#
# [251 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=df.set_index("Date")
df
# Out:
#             Close/Last    Volume     Open    High       Low
# Date
# 2018-01-02       85.95  22122680   86.125   86.31   85.5000
# 2018-01-03       86.35  25979960   86.055   86.51   85.9700
# 2018-01-04       87.11  21904860   86.590   87.66   86.5700
# 2018-01-05       88.19  23400070   87.660   88.41   87.4300
# 2018-01-08       88.28  22110230   88.200   88.58   87.6046
# ...                ...       ...      ...     ...       ...
# 2018-12-24       94.13  43935190   97.680   97.97   93.9800
# 2018-12-26      100.56  51330280   95.140  100.69   93.9600
# 2018-12-27      101.18  49162950   99.300  101.19   96.4000
# 2018-12-28      100.39  38160810  102.090  102.41   99.5200
# 2018-12-31      101.57  33161320  101.290  102.40  100.4400
#
# [251 rows x 5 columns]

# %%
plt.plot(df.index,df['Volume'])
plt.title("Volume Statistics")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %%
df=pd.read_excel("02_Microsoft.xlsx")

# %%
sns.lineplot(data=df, x="Date", y="Volume")
plt.title("Volume Statistics")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %%
df=df.set_index("Date")
df
# Out:
#             Close/Last    Volume     Open    High       Low
# Date
# 2018-01-02       85.95  22122680   86.125   86.31   85.5000
# 2018-01-03       86.35  25979960   86.055   86.51   85.9700
# 2018-01-04       87.11  21904860   86.590   87.66   86.5700
# 2018-01-05       88.19  23400070   87.660   88.41   87.4300
# 2018-01-08       88.28  22110230   88.200   88.58   87.6046
# ...                ...       ...      ...     ...       ...
# 2018-12-24       94.13  43935190   97.680   97.97   93.9800
# 2018-12-26      100.56  51330280   95.140  100.69   93.9600
# 2018-12-27      101.18  49162950   99.300  101.19   96.4000
# 2018-12-28      100.39  38160810  102.090  102.41   99.5200
# 2018-12-31      101.57  33161320  101.290  102.40  100.4400
#
# [251 rows x 5 columns]

# %%
fig,axs=plt.subplots(4,1)
axs[0].plot(df.index,df['Open'])
axs[0].set_title("Open Statistics")
axs[0].set_xlabel("Date")
axs[0].set_ylabel("Open")
axs[1].plot(df.index,df['High'])
axs[1].set_title("High Statistics")
axs[1].set_xlabel("Date")
axs[1].set_ylabel("High")
axs[2].plot(df.index,df['Low'])
axs[2].set_title("Low Statistics")
axs[2].set_xlabel("Date")
axs[2].set_ylabel("Low")
axs[3].plot(df.index,df['Close/Last'])
axs[3].set_title("Close Statistics")
axs[3].set_xlabel("Date")
axs[3].set_ylabel("Close/Last")
#plt.tight_layout()
#plt.subplot_tool()
plt.subplots_adjust(top=7.0,bottom=5.0,wspace=0.7,hspace=0.7)
plt.show()
