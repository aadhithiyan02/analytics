# %% [markdown]
# # Apple stock analysis
# ## getting info from the excel

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_excel('C:\\Users\\saadh\\Desktop\\Analytics project\\Apple.xlsx','2019')

# %% [markdown]
#  Displaying in table form

# %%
print(data)
# Out:
#           Date  Close/Last     Volume     Open     High      Low
# 0   2019-01-02     39.4800  142548280  38.7225  39.7125  38.5575
# 1   2019-01-03     35.5475  364427360  35.9950  36.4300  35.5000
# 2   2019-01-04     37.0650  229694600  36.1325  37.1375  35.9500
# 3   2019-01-07     36.9825  218285760  37.1750  37.2075  36.4750
# 4   2019-01-08     37.6875  162491640  37.3900  37.9550  37.1300
# ..         ...         ...        ...      ...      ...      ...
# 247 2019-12-24     71.0675   48478840  71.1725  71.2225  70.7299
# 248 2019-12-26     72.4775   93336000  71.2050  72.4950  71.1750
# 249 2019-12-27     72.4500  146371760  72.7800  73.4925  72.0300
# 250 2019-12-30     72.8800  144238440  72.3650  73.1725  71.3050
# 251 2019-12-31     73.4125  100990520  72.4825  73.4200  72.3800
#
# [252 rows x 6 columns]

# %% [markdown]
# Information on the columns of the table

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        252 non-null    datetime64[ns]
#  1   Close/Last  252 non-null    float64
#  2   Volume      252 non-null    int64
#  3   Open        252 non-null    float64
#  4   High        252 non-null    float64
#  5   Low         252 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 11.9 KB

# %% [markdown]
# Description on the count, minimum,maximum values in the excel file

# %%
data.describe()
# Out:
#        Close/Last        Volume        Open        High         Low
# count  252.000000  2.520000e+02  252.000000  252.000000  252.000000
# mean    52.063983  1.122429e+08   51.967270   52.457905   51.568252
# std      8.634743  4.320583e+07    8.593397    8.621378    8.576374
# min     35.547500  4.544820e+07   35.995000   36.430000   35.500000
# 25%     46.505000  8.396297e+07   46.281875   46.958125   45.879375
# 50%     50.753750  1.032711e+08   50.785000   51.178750   50.398750
# 75%     55.921250  1.281367e+08   55.873750   56.260000   55.326875
# max     73.412500  3.644274e+08   72.780000   73.492500   72.380000

# %% [markdown]
# Plotting the graph for the Close Value of Apple Stock Price in Dollars($)

# %%
plt.plot(data['Date'],data['Close/Last'],label="Close Value in $")
#plt.xlabel('Date')
#plt.ylabel("Market Price")
plt.title('Apple Close Price')
plt.legend(shadow=True)
plt.grid()
plt.show()

# %%
plt.plot(data['Date'],data['Volume'],label="Volume in 100 Million")
#plt.xlabel('Date')
#plt.ylabel("Volume")
plt.title('Stock Trade Volume')
plt.legend(shadow=True)
plt.grid()
plt.show()
