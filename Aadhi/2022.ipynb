# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %%
data=pd.read_excel('C:\\Users\\saadh\\Desktop\\Analytics project\\aapl.xlsx','2022')

# %%
print(data)
# Out:
#           Date  Close/Last     Volume    Open      High     Low
# 0   2022-01-03      182.01  104701200  177.83  182.8800  177.71
# 1   2022-01-04      179.70   99310440  182.63  182.9400  179.12
# 2   2022-01-05      174.92   94537600  179.61  180.1700  174.64
# 3   2022-01-06      172.00   96903960  172.70  175.3000  171.64
# 4   2022-01-07      172.17   86709150  172.89  174.1400  171.03
# ..         ...         ...        ...     ...       ...     ...
# 246 2022-12-23      131.86   63814890  130.92  132.4150  129.64
# 247 2022-12-27      130.03   69007830  131.38  131.4100  128.72
# 248 2022-12-28      126.04   85438390  129.67  131.0275  125.87
# 249 2022-12-29      129.61   75703710  127.99  130.4814  127.73
# 250 2022-12-30      129.93   77034210  128.41  129.9500  127.43
#
# [251 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251 entries, 0 to 250
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        251 non-null    datetime64[ns]
#  1   Close/Last  251 non-null    float64
#  2   Volume      251 non-null    int64
#  3   Open        251 non-null    float64
#  4   High        251 non-null    float64
#  5   Low         251 non-null    float64
# dtypes: datetime64[ns](1), float64(4), int64(1)
# memory usage: 11.9 KB

# %%
data.describe()
# Out:
#        Close/Last        Volume        Open        High         Low
# count  251.000000  2.510000e+02  251.000000  251.000000  251.000000
# mean   154.835060  8.792501e+07  154.802398  156.907665  152.691186
# std     13.056081  2.365237e+07   13.063052   12.937480   13.107969
# min    126.040000  3.519586e+07  127.990000  129.950000  125.870000
# 25%    144.645000  7.229738e+07  144.327500  146.710000  142.325050
# 50%    154.090000  8.376380e+07  154.010000  155.830000  151.940000
# 75%    165.915000  9.693703e+07  166.187500  167.989950  164.045000
# max    182.010000  1.826020e+08  182.630000  182.940000  179.120000

# %%
plt.plot(data['Date'],data['Close/Last'],label="Close Value in $")
#plt.xlabel('Date')
#plt.ylabel("Market Price")
plt.title('Apple Close Price')
plt.legend(shadow=True)
plt.grid()
plt.show()

# %%
plt.plot(data['Date'],data['Volume'],label="Volume in 100 Million")
#plt.xlabel('Date')
#plt.ylabel("Volume")
plt.title('Stock Trade Volume')
plt.legend(shadow=True)
plt.grid()
plt.show()
