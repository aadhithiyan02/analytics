# %%
import pandas as pd
df=pd.read_excel("2022.xlsx")
df
# Out:
#           Date  Close/Last    Volume    Open    High       Low
# 0   2022-01-03      334.75  28918010  335.35  338.00  329.7800
# 1   2022-01-04      329.01  32674310  334.83  335.20  326.1200
# 2   2022-01-05      316.38  40054330  325.86  326.07  315.9800
# 3   2022-01-06      313.88  39646150  313.15  318.70  311.4900
# 4   2022-01-07      314.04  32720020  314.15  316.50  310.0900
# ..         ...         ...       ...     ...     ...       ...
# 246 2022-12-23      238.73  21206980  236.11  238.87  233.9428
# 247 2022-12-27      236.96  16688650  238.70  238.93  235.8300
# 248 2022-12-28      234.53  17457100  236.89  239.72  234.1700
# 249 2022-12-29      241.01  19770690  235.65  241.92  235.6500
# 250 2022-12-30      239.82  21938470  238.21  239.96  236.6600
#
# [251 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=df.set_index("Date")
df
# Out:
#             Close/Last    Volume    Open    High       Low
# Date
# 2022-01-03      334.75  28918010  335.35  338.00  329.7800
# 2022-01-04      329.01  32674310  334.83  335.20  326.1200
# 2022-01-05      316.38  40054330  325.86  326.07  315.9800
# 2022-01-06      313.88  39646150  313.15  318.70  311.4900
# 2022-01-07      314.04  32720020  314.15  316.50  310.0900
# ...                ...       ...     ...     ...       ...
# 2022-12-23      238.73  21206980  236.11  238.87  233.9428
# 2022-12-27      236.96  16688650  238.70  238.93  235.8300
# 2022-12-28      234.53  17457100  236.89  239.72  234.1700
# 2022-12-29      241.01  19770690  235.65  241.92  235.6500
# 2022-12-30      239.82  21938470  238.21  239.96  236.6600
#
# [251 rows x 5 columns]

# %%
plt.plot(df.index,df['Volume'])
plt.title("Volume Statistics")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %%
fig,axs=plt.subplots(4,1)
axs[0].plot(df.index,df['Open'])
axs[0].set_title("Open Statistics")
axs[0].set_xlabel("Date")
axs[0].set_ylabel("Open")
axs[1].plot(df.index,df['High'])
axs[1].set_title("High Statistics")
axs[1].set_xlabel("Date")
axs[1].set_ylabel("High")
axs[2].plot(df.index,df['Low'])
axs[2].set_title("Low Statistics")
axs[2].set_xlabel("Date")
axs[2].set_ylabel("Low")
axs[3].plot(df.index,df['Close/Last'])
axs[3].set_title("Close Statistics")
axs[3].set_xlabel("Date")
axs[3].set_ylabel("Close/Last")
#plt.tight_layout()
#plt.subplot_tool()
plt.subplots_adjust(top=7.0,bottom=5.0,wspace=0.7,hspace=0.7)
plt.show()

# %%
#sns.heatmap(df.corr(), annot="true", cmap="YlGnBu")
