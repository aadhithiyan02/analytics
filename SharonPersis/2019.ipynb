# %%
import pandas as pd
df=pd.read_excel("2019.xlsx")
df
# Out:
#           Date  Close/Last    Volume     Open      High       Low
# 0   2019-01-02      101.12  35145360   99.550  101.7500   98.9400
# 1   2019-01-03       97.40  42111650  100.100  100.1850   97.2000
# 2   2019-01-04      101.93  43982700   99.720  102.5100   98.9300
# 3   2019-01-07      102.06  35567820  101.640  103.2681  100.9800
# 4   2019-01-08      102.80  31322920  103.040  103.9700  101.7134
# ..         ...         ...       ...      ...       ...       ...
# 247 2019-12-24      157.38   8989150  157.480  157.7100  157.1150
# 248 2019-12-26      158.67  14526930  157.560  158.7300  157.4000
# 249 2019-12-27      158.96  18414350  159.450  159.5500  158.2200
# 250 2019-12-30      157.59  16356720  158.987  159.0200  156.7300
# 251 2019-12-31      157.70  18393380  156.770  157.7700  156.4500
#
# [252 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=df.set_index("Date")
df
# Out:
#             Close/Last    Volume     Open      High       Low
# Date
# 2019-01-02      101.12  35145360   99.550  101.7500   98.9400
# 2019-01-03       97.40  42111650  100.100  100.1850   97.2000
# 2019-01-04      101.93  43982700   99.720  102.5100   98.9300
# 2019-01-07      102.06  35567820  101.640  103.2681  100.9800
# 2019-01-08      102.80  31322920  103.040  103.9700  101.7134
# ...                ...       ...      ...       ...       ...
# 2019-12-24      157.38   8989150  157.480  157.7100  157.1150
# 2019-12-26      158.67  14526930  157.560  158.7300  157.4000
# 2019-12-27      158.96  18414350  159.450  159.5500  158.2200
# 2019-12-30      157.59  16356720  158.987  159.0200  156.7300
# 2019-12-31      157.70  18393380  156.770  157.7700  156.4500
#
# [252 rows x 5 columns]

# %%
plt.plot(df.index,df['Volume'])
plt.title("Volume Statistics")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %%
df=df.set_index("Date")
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-f9a95bc720bb> in <module>
# ----> 1 df=df.set_index("Date")
#       2 df
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Date'] are in the columns"

# %%
fig,axs=plt.subplots(4,1)
axs[0].plot(df.index,df['Open'])
axs[0].set_title("Open Statistics")
axs[0].set_xlabel("Date")
axs[0].set_ylabel("Open")
axs[1].plot(df.index,df['High'])
axs[1].set_title("High Statistics")
axs[1].set_xlabel("Date")
axs[1].set_ylabel("High")
axs[2].plot(df.index,df['Low'])
axs[2].set_title("Low Statistics")
axs[2].set_xlabel("Date")
axs[2].set_ylabel("Low")
axs[3].plot(df.index,df['Close/Last'])
axs[3].set_title("Close Statistics")
axs[3].set_xlabel("Date")
axs[3].set_ylabel("Close/Last")
#plt.tight_layout()
#plt.subplot_tool()
plt.subplots_adjust(top=7.0,bottom=5.0,wspace=0.7,hspace=0.7)
plt.show()

# %%
#sns.heatmap(df.corr(), annot="true", cmap="YlGnBu")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-0bcf5c0ae2bc> in <module>
# ----> 1 sns.heatmap(df.corr(), annot="true", cmap="YlGnBu")
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     510     plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     511                           annot_kws, cbar, cbar_kws, xticklabels,
# --> 512                           yticklabels, mask)
#     513
#     514     # Add the pcolormesh kwargs here
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\matrix.py in __init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     177                 if annot_data.shape != plot_data.shape:
#     178                     err = "`data` and `annot` must have same shape."
# --> 179                     raise ValueError(err)
#     180             annot = True
#     181
#
# ValueError: `data` and `annot` must have same shape.
