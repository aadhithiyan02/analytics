# %%
import pandas as pd
data=pd.read_excel("2019.xlsx")
data=data.set_index("Date")
data
# Out:
#             Close/Last    Volume     Open     High      Low
# Date
# 2019-01-02     52.7340  31650480  51.3600  53.0395  51.2638
# 2019-01-03     51.2735  41898580  52.5335  53.3130  51.1185
# 2019-01-04     53.9035  46020840  52.1280  54.0000  51.8430
# 2019-01-07     53.7960  47430760  54.0485  54.1350  53.1320
# 2019-01-08     54.2685  35192800  54.3000  54.6675  53.4174
# ...                ...       ...      ...      ...      ...
# 2019-12-24     67.2215  13468200  67.5105  67.6005  67.2083
# 2019-12-26     68.1235  23676000  67.3275  68.1600  67.2755
# 2019-12-27     67.7320  23217460  68.2000  68.3535  67.6500
# 2019-12-30     66.9855  20011840  67.8405  67.8500  66.8918
# 2019-12-31     66.9695  19521220  66.7895  67.0330  66.6065
#
# [252 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.plot(data.index,data["Volume"])
plt.title("Volume Statistics")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %%
fig,axs=plt.subplots(4,1)
axs[0].plot(data.index,data["Open"])
axs[0].set_title("Open statistics")
axs[0].set_xlabel("Date")
axs[0].set_ylabel("Open")
axs[1].plot(data.index,data["High"])
axs[1].set_title("High statistics")
axs[1].set_xlabel("Date")
axs[1].set_ylabel("High")
axs[2].plot(data.index,data["Low"])
axs[2].set_title("Low statistics")
axs[2].set_xlabel("Date")
axs[2].set_ylabel("Low")
axs[3].plot(data.index,data["Close/Last"])
axs[3].set_title("Close statistics")
axs[3].set_xlabel("Date")
axs[3].set_ylabel("Close")
plt.subplots_adjust(top=7.0,bottom=5.0,wspace=1.0,hspace=1.0)
