# %%
import pandas as pd
data=pd.read_excel("2022.xlsx")
data=data.set_index("Date")
data
# Out:
#             Close/Last    Volume      Open      High       Low
# Date
# 2022-01-03    144.9915  28678940  145.0550  145.8510  143.7128
# 2022-01-04    144.3995  28399440  145.3960  146.4849  143.7163
# 2022-01-05    137.7750  54618280  144.4200  144.4994  137.6880
# 2022-01-06    137.7475  37347420  136.9985  139.9400  136.5585
# 2022-01-07    137.0170  29760560  138.1455  138.4485  135.7665
# ...                ...       ...       ...       ...       ...
# 2022-12-23     89.2300  23003040   87.1100   89.5450   87.0700
# 2022-12-27     87.3900  20097350   88.7950   88.9400   87.0100
# 2022-12-28     86.0200  19523180   86.9800   88.0400   85.9400
# 2022-12-29     88.4500  23333540   86.6200   88.8450   86.6100
# 2022-12-30     88.2300  23986300   86.9800   88.3000   86.5700
#
# [251 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.plot(data.index,data["Volume"])
plt.title("Volume Statistics")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %%
fig,axs=plt.subplots(4,1)
axs[0].plot(data.index,data["Open"])
axs[0].set_title("Open statistics")
axs[0].set_xlabel("Date")
axs[0].set_ylabel("Open")
axs[1].plot(data.index,data["High"])
axs[1].set_title("High statistics")
axs[1].set_xlabel("Date")
axs[1].set_ylabel("High")
axs[2].plot(data.index,data["Low"])
axs[2].set_title("Low statistics")
axs[2].set_xlabel("Date")
axs[2].set_ylabel("Low")
axs[3].plot(data.index,data["Close/Last"])
axs[3].set_title("Close statistics")
axs[3].set_xlabel("Date")
axs[3].set_ylabel("Close")
plt.subplots_adjust(top=7.0,bottom=5.0,wspace=1.0,hspace=1.0)
