# %%
import pandas as pd
data=pd.read_excel("2020.xlsx")
data=data.set_index("Date")
data
# Out:
#             Close/Last    Volume     Open     High      Low
# Date
# 2020-01-02     68.4340  27285300  67.4205  68.4340  67.3245
# 2020-01-03     68.0760  23412580  67.4000  68.6875  67.3662
# 2020-01-06     69.8905  46786860  67.5815  69.9160  67.5500
# 2020-01-07     69.7555  34529120  70.0230  70.1750  69.5778
# 2020-01-08     70.2520  35325480  69.7410  70.5925  69.6315
# ...                ...       ...      ...      ...      ...
# 2020-12-24     86.7080   9312760  86.4500  87.1205  86.2175
# 2020-12-28     88.6980  27650740  87.2455  89.3500  87.0910
# 2020-12-29     87.8880  19725740  89.3615  89.4235  87.7555
# 2020-12-30     86.8125  21026160  88.2500  88.3880  86.4000
# 2020-12-31     87.6320  21069580  86.8635  87.8750  86.8045
#
# [253 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.plot(data.index,data["Volume"])
plt.title("Volume Statistics")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %%
fig,axs=plt.subplots(4,1)
axs[0].plot(data.index,data["Open"])
axs[0].set_title("Open statistics")
axs[0].set_xlabel("Date")
axs[0].set_ylabel("Open")
axs[1].plot(data.index,data["High"])
axs[1].set_title("High statistics")
axs[1].set_xlabel("Date")
axs[1].set_ylabel("High")
axs[2].plot(data.index,data["Low"])
axs[2].set_title("Low statistics")
axs[2].set_xlabel("Date")
axs[2].set_ylabel("Low")
axs[3].plot(data.index,data["Close/Last"])
axs[3].set_title("Close statistics")
axs[3].set_xlabel("Date")
axs[3].set_ylabel("Close")
plt.subplots_adjust(top=7.0,bottom=5.0,wspace=1.0,hspace=1.0)
