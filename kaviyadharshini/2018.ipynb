# %%
import pandas as pd
data=pd.read_excel("06_Google.xlsx")
data=data.set_index("Date")
data
# Out:
#             Close/Last      Volume     Open     High      Low
# Date
# 2018-01-02     53.6605  31747160.0  52.6510  53.7990  52.6510
# 2018-01-03     54.5760  31288200.0  53.6965  54.8050  53.6715
# 2018-01-04     54.7880  26049400.0  54.8545  55.2038  54.7130
# 2018-01-05     55.5145  30249860.0  55.1725  55.6790  55.0898
# 2018-01-08     55.7105  24626880.0  55.5500  55.9580  55.5000
# ...                ...         ...      ...      ...      ...
# 2018-12-24     49.2335  36359100.0  49.2160  50.6060  48.8830
# 2018-12-26     52.3925  46134200.0  49.8995  52.4225  49.6322
# 2018-12-27     52.6450  45319680.0  51.3100  52.6670  50.3500
# 2018-12-28     52.3340  34360360.0  52.9750  53.2115  52.1000
# 2018-12-31     52.2480  33084180.0  52.8915  53.1495  51.6519
#
# [251 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.plot(data.index,data["Volume"])
plt.title("Volume Statistics")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %%
fig,axs=plt.subplots(4,1)
axs[0].plot(data.index,data["Open"])
axs[0].set_title("Open statistics")
axs[0].set_xlabel("Date")
axs[0].set_ylabel("Open")
axs[1].plot(data.index,data["High"])
axs[1].set_title("High statistics")
axs[1].set_xlabel("Date")
axs[1].set_ylabel("High")
axs[2].plot(data.index,data["Low"])
axs[2].set_title("Low statistics")
axs[2].set_xlabel("Date")
axs[2].set_ylabel("Low")
axs[3].plot(data.index,data["Close/Last"])
axs[3].set_title("Close statistics")
axs[3].set_xlabel("Date")
axs[3].set_ylabel("Close")
plt.subplots_adjust(top=7.0,bottom=5.0,wspace=1.0,hspace=1.0)
