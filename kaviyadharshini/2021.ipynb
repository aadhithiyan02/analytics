# %%
import pandas as pd
data=pd.read_excel("2021.xlsx")
data=data.set_index("Date")
data
# Out:
#             Close/Last    Volume      Open      High       Low
# Date
# 2021-01-04     86.3065  37323900   88.0000   88.1245   85.3570
# 2021-01-05     87.0025  20359240   86.2545   87.3415   85.8450
# 2021-01-06     86.1440  46588020   85.0128   87.1983   84.8051
# 2021-01-07     88.7170  41936580   86.3380   88.8910   86.3380
# 2021-01-08     89.8915  35484520   88.8580   89.9678   88.0610
# ...                ...       ...       ...       ...       ...
# 2021-12-27    147.9065  15984460  147.2560  148.3440  147.1693
# 2021-12-28    146.6870  18254300  148.2360  148.2990  146.0543
# 2021-12-29    146.6550  17787460  146.6443  147.4170  145.6475
# 2021-12-30    146.2005  15687720  146.6940  147.3000  145.9945
# 2021-12-31    144.8520  18135180  146.0500  146.6985  144.8520
#
# [252 rows x 5 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.plot(data.index,data["Volume"])
plt.title("Volume Statistics")
plt.xlabel("Date")
plt.ylabel("Volume")
plt.show()

# %%
fig,axs=plt.subplots(4,1)
axs[0].plot(data.index,data["Open"])
axs[0].set_title("Open statistics")
axs[0].set_xlabel("Date")
axs[0].set_ylabel("Open")
axs[1].plot(data.index,data["High"])
axs[1].set_title("High statistics")
axs[1].set_xlabel("Date")
axs[1].set_ylabel("High")
axs[2].plot(data.index,data["Low"])
axs[2].set_title("Low statistics")
axs[2].set_xlabel("Date")
axs[2].set_ylabel("Low")
axs[3].plot(data.index,data["Close/Last"])
axs[3].set_title("Close statistics")
axs[3].set_xlabel("Date")
axs[3].set_ylabel("Close")
plt.subplots_adjust(top=7.0,bottom=5.0,wspace=1.0,hspace=1.0)
